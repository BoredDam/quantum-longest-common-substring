# %%
'''
tests_3bit = [
    ("001010011100101110000000", "001010011100101110111111"),
    ("010011100101110001010000", "010011100101110001010111"),
    ("011100101110001010000000", "011100101110001010111111"),
    ("100101110001010011100000", "100101110001010011100111"),
    ("101110001010011100000000", "101110001010011100111111"),
    ("110001010011100101000000", "110001010011100101111111"),
    ("001011101010100110000000", "001011101010100110111111"),
    ("010100110101001011000000", "010100110101001011111111"),
    ("011001101100010101000000", "011001101100010101111111"),
    ("100010101001011110000000", "100010101001011110111111"),
    ("101001011010100110000000", "101001011010100110111111"),
    ("110100101001101010000000", "110100101001101010111111"),
    ("001100101010110001000000", "001100101010110001111111"),
    ("010101001100110010000000", "010101001100110010111111"),
    ("011110100101001100000000", "011110100101001100111111"),
    ("100001011010110100000000", "100001011010110100111111"),
    ("101010100110001011000000", "101010100110001011111111"),
    ("110011001010100101000000", "110011001010100101111111"),
    ("001101010011001100000000", "001101010011001100111111"),
    ("010110001101010100000000", "010110001101010100111111"),
]

passed = 0
failed = 0

for X, Y in tests_3bit:
    print(f"X = '{X}'")
    print(f"Y = '{Y}'")
    expected = classical_lcs_substring_len(X, Y, 3)
    actual = quantum_LCS(X, Y, 8, 3, True)
    print("atteso =", expected, "| ottenuto =", actual)

    if expected == actual:
        passed += 1
        print(f"passed! till now: {passed}")
    else:
        failed += 1
        print(f"failed! till now: {failed}")

print(passed)
print(failed)
'''
# Out:
# '\ntests_3bit = [\n    ("001010011100101110000000", "001010011100101110111111"),\n    ("010011100101110001010000", "010011100101110001010111"),\n    ("011100101110001010000000", "011100101110001010111111"),\n    ("100101110001010011100000", "100101110001010011100111"),\n    ("101110001010011100000000", "101110001010011100111111"),\n    ("110001010011100101000000", "110001010011100101111111"),\n    ("001011101010100110000000", "001011101010100110111111"),\n    ("010100110101001011000000", "010100110101001011111111"),\n    ("011001101100010101000000", "011001101100010101111111"),\n    ("100010101001011110000000", "100010101001011110111111"),\n    ("101001011010100110000000", "101001011010100110111111"),\n    ("110100101001101010000000", "110100101001101010111111"),\n    ("001100101010110001000000", "001100101010110001111111"),\n    ("010101001100110010000000", "010101001100110010111111"),\n    ("011110100101001100000000", "011110100101001100111111"),\n    ("100001011010110100000000", "100001011010110100111111"),\n    ("101010100110001011000000", "101010100110001011111111"),\n    ("110011001010100101000000", "110011001010100101111111"),\n    ("001101010011001100000000", "001101010011001100111111"),\n    ("010110001101010100000000", "010110001101010100111111"),\n]\n\npassed = 0\nfailed = 0\n\nfor X, Y in tests_3bit:\n    print(f"X = \'{X}\'")\n    print(f"Y = \'{Y}\'")\n    expected = classical_lcs_substring_len(X, Y, 3)\n    actual = quantum_LCS(X, Y, 8, 3, True)\n    print("atteso =", expected, "| ottenuto =", actual)\n\n    if expected == actual:\n        passed += 1\n        print(f"passed! till now: {passed}")\n    else:\n        failed += 1\n        print(f"failed! till now: {failed}")\n\nprint(passed)\nprint(failed)\n'

# %%
'''
def dna_random_strings(max_len: int):
    length = np.random.randint(3, max_len)
    rand = np.random.randint(0, 4, size=length)
    mapping = ['A','G','C','T' ]
    out = ""

    for r in rand:
        out += mapping[r]
    return out

dna1 = 'CAAAC'
dna2 = 'GAAGCGG'

def fix_shape_dna_lcs_problem(dna1: str, dna2: str, out_len: int):
    input_len1 = len(dna1)
    input_len2 = len(dna2)
    dna1 = dna1 + '$'*(out_len - input_len1)
    dna2 = dna2 + '%'*(out_len - input_len2)
    return dna1, dna2

X, Y = fix_shape_dna_lcs_problem(dna1, dna2, 8)

def dna_to_lcs_problem(dna_seq1: str, dna_seq2: str='0'):
    mapping = {
    'A': '001', 'G': '010',
    'C': '011', 'T': '100',
    '$': '000', '%': '111'
    }

    out1 = ""
    out2 = ""

    for c in dna_seq1:
        out1 += mapping.get(c)

    if dna_seq2 == '0':
        return out1
    else:
        for c in dna_seq2:
            out2 += mapping.get(c)
    
    return out1, out2

X, Y = dna_to_lcs_problem(X, Y)

quantum_LCS(X, Y, MAX_LEN, 3, True)
'''
# Out:
# '\ndef dna_random_strings(max_len: int):\n    length = np.random.randint(3, max_len)\n    rand = np.random.randint(0, 4, size=length)\n    mapping = [\'A\',\'G\',\'C\',\'T\' ]\n    out = ""\n\n    for r in rand:\n        out += mapping[r]\n    return out\n\ndna1 = \'CAAAC\'\ndna2 = \'GAAGCGG\'\n\ndef fix_shape_dna_lcs_problem(dna1: str, dna2: str, out_len: int):\n    input_len1 = len(dna1)\n    input_len2 = len(dna2)\n    dna1 = dna1 + \'$\'*(out_len - input_len1)\n    dna2 = dna2 + \'%\'*(out_len - input_len2)\n    return dna1, dna2\n\nX, Y = fix_shape_dna_lcs_problem(dna1, dna2, 8)\n\ndef dna_to_lcs_problem(dna_seq1: str, dna_seq2: str=\'0\'):\n    mapping = {\n    \'A\': \'001\', \'G\': \'010\',\n    \'C\': \'011\', \'T\': \'100\',\n    \'$\': \'000\', \'%\': \'111\'\n    }\n\n    out1 = ""\n    out2 = ""\n\n    for c in dna_seq1:\n        out1 += mapping.get(c)\n\n    if dna_seq2 == \'0\':\n        return out1\n    else:\n        for c in dna_seq2:\n            out2 += mapping.get(c)\n\n    return out1, out2\n\nX, Y = dna_to_lcs_problem(X, Y)\n\nquantum_LCS(X, Y, MAX_LEN, 3, True)\n'

# %%
'''
def dna_random_strings(max_len: int):
    length = np.random.randint(3, max_len)
    rand = np.random.randint(0, 4, size=length)
    mapping = ['A','G','C','T' ]
    out = ""

    for r in rand:
        out += mapping[r]
    return out

dna1 = 'CAAAC'
dna2 = 'GAAGCGG'

def fix_shape_dna_lcs_problem(dna1: str, dna2: str, out_len: int):
    input_len1 = len(dna1)
    input_len2 = len(dna2)
    dna1 = dna1 + '$'*(out_len - input_len1)
    dna2 = dna2 + '%'*(out_len - input_len2)
    return dna1, dna2

X, Y = fix_shape_dna_lcs_problem(dna1, dna2, 8)

def dna_to_lcs_problem(dna_seq1: str, dna_seq2: str='0'):
    mapping = {
    'A': '001', 'G': '010',
    'C': '011', 'T': '100',
    '$': '000', '%': '111'
    }

    out1 = ""
    out2 = ""

    for c in dna_seq1:
        out1 += mapping.get(c)

    if dna_seq2 == '0':
        return out1
    else:
        for c in dna_seq2:
            out2 += mapping.get(c)
    
    return out1, out2

X, Y = dna_to_lcs_problem(X, Y)

quantum_LCS(X, Y, MAX_LEN, 3, True)
'''
# Out:
# '\ndef dna_random_strings(max_len: int):\n    length = np.random.randint(3, max_len)\n    rand = np.random.randint(0, 4, size=length)\n    mapping = [\'A\',\'G\',\'C\',\'T\' ]\n    out = ""\n\n    for r in rand:\n        out += mapping[r]\n    return out\n\ndna1 = \'CAAAC\'\ndna2 = \'GAAGCGG\'\n\ndef fix_shape_dna_lcs_problem(dna1: str, dna2: str, out_len: int):\n    input_len1 = len(dna1)\n    input_len2 = len(dna2)\n    dna1 = dna1 + \'$\'*(out_len - input_len1)\n    dna2 = dna2 + \'%\'*(out_len - input_len2)\n    return dna1, dna2\n\nX, Y = fix_shape_dna_lcs_problem(dna1, dna2, 8)\n\ndef dna_to_lcs_problem(dna_seq1: str, dna_seq2: str=\'0\'):\n    mapping = {\n    \'A\': \'001\', \'G\': \'010\',\n    \'C\': \'011\', \'T\': \'100\',\n    \'$\': \'000\', \'%\': \'111\'\n    }\n\n    out1 = ""\n    out2 = ""\n\n    for c in dna_seq1:\n        out1 += mapping.get(c)\n\n    if dna_seq2 == \'0\':\n        return out1\n    else:\n        for c in dna_seq2:\n            out2 += mapping.get(c)\n\n    return out1, out2\n\nX, Y = dna_to_lcs_problem(X, Y)\n\nquantum_LCS(X, Y, MAX_LEN, 3, True)\n'
